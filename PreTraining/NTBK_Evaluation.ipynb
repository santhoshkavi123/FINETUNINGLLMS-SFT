# %%
# !pip install -U git+https://github.com/EleutherAI/lm-evaluation-harness
# Out:
# Collecting git+https://github.com/EleutherAI/lm-evaluation-harness
#   Cloning https://github.com/EleutherAI/lm-evaluation-harness to /tmp/pip-req-build-tkutx5mo
#   Running command git clone --filter=blob:none --quiet https://github.com/EleutherAI/lm-evaluation-harness /tmp/pip-req-build-tkutx5mo
#   Resolved https://github.com/EleutherAI/lm-evaluation-harness to commit 01e412089bdb7590cb75d43310ac0b67c72938fa
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: datasets>=2.16.0 in /usr/local/lib/python3.12/dist-packages (from lm_eval==0.4.9.2) (4.0.0)
# Collecting evaluate>=0.4.0 (from lm_eval==0.4.9.2)
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from lm_eval==0.4.9.2) (3.1.6)
# Collecting jsonlines (from lm_eval==0.4.9.2)
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting pytablewriter (from lm_eval==0.4.9.2)
#   Downloading pytablewriter-1.2.1-py3-none-any.whl.metadata (38 kB)
# Collecting rouge-score>=0.0.4 (from lm_eval==0.4.9.2)
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sacrebleu>=1.5.0 (from lm_eval==0.4.9.2)
#   Downloading sacrebleu-2.5.1-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from lm_eval==0.4.9.2) (1.6.1)
# Collecting sqlitedict (from lm_eval==0.4.9.2)
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: zstandard in /usr/local/lib/python3.12/dist-packages (from lm_eval==0.4.9.2) (0.25.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from lm_eval==0.4.9.2) (0.3.8)
# Collecting word2number (from lm_eval==0.4.9.2)
#   Downloading word2number-1.1.zip (9.7 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.12/dist-packages (from lm_eval==0.4.9.2) (10.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=2.16.0->lm_eval==0.4.9.2) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.16.0->lm_eval==0.4.9.2) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.16.0->lm_eval==0.4.9.2) (18.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets>=2.16.0->lm_eval==0.4.9.2) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.16.0->lm_eval==0.4.9.2) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.16.0->lm_eval==0.4.9.2) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=2.16.0->lm_eval==0.4.9.2) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.16.0->lm_eval==0.4.9.2) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->lm_eval==0.4.9.2) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.16.0->lm_eval==0.4.9.2) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets>=2.16.0->lm_eval==0.4.9.2) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.16.0->lm_eval==0.4.9.2) (6.0.3)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from rouge-score>=0.0.4->lm_eval==0.4.9.2) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (from rouge-score>=0.0.4->lm_eval==0.4.9.2) (3.9.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from rouge-score>=0.0.4->lm_eval==0.4.9.2) (1.17.0)
# Collecting portalocker (from sacrebleu>=1.5.0->lm_eval==0.4.9.2)
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.9.2) (2025.11.3)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.12/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.9.2) (0.9.0)
# Collecting colorama (from sacrebleu>=1.5.0->lm_eval==0.4.9.2)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.9.2) (6.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.24.1->lm_eval==0.4.9.2) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.24.1->lm_eval==0.4.9.2) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.24.1->lm_eval==0.4.9.2) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->lm_eval==0.4.9.2) (3.0.3)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonlines->lm_eval==0.4.9.2) (25.4.0)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.12/dist-packages (from pytablewriter->lm_eval==0.4.9.2) (75.2.0)
# Collecting DataProperty<2,>=1.1.0 (from pytablewriter->lm_eval==0.4.9.2)
#   Downloading DataProperty-1.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter->lm_eval==0.4.9.2)
#   Downloading mbstrdecoder-1.1.4-py3-none-any.whl.metadata (4.3 kB)
# Collecting pathvalidate<4,>=2.3.0 (from pytablewriter->lm_eval==0.4.9.2)
#   Downloading pathvalidate-3.3.1-py3-none-any.whl.metadata (12 kB)
# Collecting tabledata<2,>=1.3.1 (from pytablewriter->lm_eval==0.4.9.2)
#   Downloading tabledata-1.3.4-py3-none-any.whl.metadata (3.7 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter->lm_eval==0.4.9.2)
#   Downloading tcolorpy-0.1.7-py3-none-any.whl.metadata (6.3 kB)
# Collecting typepy<2,>=1.3.2 (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm_eval==0.4.9.2)
#   Downloading typepy-1.3.4-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->lm_eval==0.4.9.2) (3.13.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets>=2.16.0->lm_eval==0.4.9.2) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets>=2.16.0->lm_eval==0.4.9.2) (1.2.0)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.12/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter->lm_eval==0.4.9.2) (5.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.16.0->lm_eval==0.4.9.2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.16.0->lm_eval==0.4.9.2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.16.0->lm_eval==0.4.9.2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.16.0->lm_eval==0.4.9.2) (2025.11.12)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm_eval==0.4.9.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.12/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm_eval==0.4.9.2) (2025.2)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk->rouge-score>=0.0.4->lm_eval==0.4.9.2) (8.3.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=2.16.0->lm_eval==0.4.9.2) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->lm_eval==0.4.9.2) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->lm_eval==0.4.9.2) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->lm_eval==0.4.9.2) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->lm_eval==0.4.9.2) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->lm_eval==0.4.9.2) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->lm_eval==0.4.9.2) (1.22.0)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 7.2 MB/s eta 0:00:00
# Downloading sacrebleu-2.5.1-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 9.6 MB/s eta 0:00:00
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading pytablewriter-1.2.1-py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 7.6 MB/s eta 0:00:00
# Downloading DataProperty-1.1.0-py3-none-any.whl (27 kB)
# Downloading mbstrdecoder-1.1.4-py3-none-any.whl (7.9 kB)
# Downloading pathvalidate-3.3.1-py3-none-any.whl (24 kB)
# Downloading tabledata-1.3.4-py3-none-any.whl (11 kB)
# Downloading tcolorpy-0.1.7-py3-none-any.whl (8.1 kB)
# Downloading typepy-1.3.4-py3-none-any.whl (31 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Building wheels for collected packages: lm_eval, rouge-score, sqlitedict, word2number
#   Building wheel for lm_eval (pyproject.toml) ... done
#   Created wheel for lm_eval: filename=lm_eval-0.4.9.2-py3-none-any.whl size=8280405 sha256=1dc7d5eee996b2e414efb63afe7755975f9706bf884afd6d6507a9d018778e04
#   Stored in directory: /tmp/pip-ephem-wheel-cache-aohreev0/wheels/2c/5d/7c/0484b25d9edc422de690ba7f7015463da9a15793760908f78b
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=1f3f579a5bbcd0540fe347db8f202f2adf6328fce12bc96d0c57c20cdaafd2f9
#   Stored in directory: /root/.cache/pip/wheels/85/9d/af/01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16862 sha256=74048201250bd9259c08fd69f0cdfb55fd78709c2bb0d402a9e91d491492950c
#   Stored in directory: /root/.cache/pip/wheels/7a/6f/21/fc016aef45ffcabe27129a2252f061387cbf278d2086225a64
#   Building wheel for word2number (setup.py) ... done
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5568 sha256=06db466bb245378d6ff1260c0f07653c623b5bdfd8a32d5fc1897ab75e24b049
#   Stored in directory: /root/.cache/pip/wheels/5b/79/fb/d25928e599c7e11fe4e00d32048cd74933f34a74c633d2aea6
# Successfully built lm_eval rouge-score sqlitedict word2number
# Installing collected packages: word2number, sqlitedict, tcolorpy, portalocker, pathvalidate, mbstrdecoder, jsonlines, colorama, typepy, sacrebleu, rouge-score, DataProperty, tabledata, evaluate, pytablewriter, lm_eval
# Successfully installed DataProperty-1.1.0 colorama-0.4.6 evaluate-0.4.6 jsonlines-4.0.0 lm_eval-0.4.9.2 mbstrdecoder-1.1.4 pathvalidate-3.3.1 portalocker-3.2.0 pytablewriter-1.2.1 rouge-score-0.1.2 sacrebleu-2.5.1 sqlitedict-2.1.0 tabledata-1.3.4 tcolorpy-0.1.7 typepy-1.3.4 word2number-1.1

# %%
import os

def h6_open_llm_leaderboard(model_name):
  task_and_shot = [
      ('arc_challenge', 25),
      ('hellaswag', 10),
      ('mmlu', 5),
      ('truthfulqa_mc2', 0),
      ('winogrande', 5),
      ('gsm8k', 5)
  ]

  for task, fewshot in task_and_shot:
    eval_cmd = f"""
    lm_eval --model hf \
        --model_args pretrained={model_name} \
        --tasks {task} \
        --device cuda \
        --num_fewshot {fewshot}
    """
    os.system(eval_cmd)

h6_open_llm_leaderboard(model_name="SanKav123/output")
